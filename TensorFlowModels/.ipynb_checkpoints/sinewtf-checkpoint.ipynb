# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

x=np.linspace(0,2*np.pi,360)
y=np.sin(x)

x_train = x
y_train = y

W1 = tf.Variable(tf.random.normal([1]), trainable = True, name='weight')
b1 = tf.Variable(tf.random.normal([1]), trainable = True, name='bias')

W2 = tf.Variable(tf.random.normal([1]), trainable = True, name='weight')
b2 = tf.Variable(tf.random.normal([1]), trainable = True, name='bias')

@tf.function
def cost(W, b):
    y_model = (W1 * x_train + b1)*W2+b2
    error = tf.reduce_mean(tf.square(y_train - y_model))
    return error


optimizer = tf.optimizers.SGD(learning_rate=0.01)

trainable_vars = [W1,b1,W2,b2]

epochs = 100 #(or however many iterations you want it to run)
for _ in range(epochs):
    with tf.GradientTape() as tp:
        #your loss/cost function must always be contained within the gradient tape instantiation
        cost_fn = cost(W, b)
    print(cost_fn)
    gradients = tp.gradient(cost_fn, trainable_vars)
    optimizer.apply_gradients(zip(gradients, trainable_vars))

tf.print(W)
tf.print(b)
# Out:
# tf.Tensor(6.9780545, shape=(), dtype=float32)
# tf.Tensor(3.7244663, shape=(), dtype=float32)
# tf.Tensor(2.032225, shape=(), dtype=float32)
# tf.Tensor(1.1520638, shape=(), dtype=float32)
# tf.Tensor(0.69427836, shape=(), dtype=float32)
# tf.Tensor(0.45617658, shape=(), dtype=float32)
# tf.Tensor(0.33233592, shape=(), dtype=float32)
# tf.Tensor(0.26792407, shape=(), dtype=float32)
# tf.Tensor(0.23442209, shape=(), dtype=float32)
# tf.Tensor(0.2169968, shape=(), dtype=float32)
# tf.Tensor(0.20793326, shape=(), dtype=float32)
# tf.Tensor(0.20321876, shape=(), dtype=float32)
# tf.Tensor(0.20076631, shape=(), dtype=float32)
# tf.Tensor(0.19949035, shape=(), dtype=float32)
# tf.Tensor(0.19882634, shape=(), dtype=float32)
# tf.Tensor(0.1984806, shape=(), dtype=float32)
# tf.Tensor(0.19830038, shape=(), dtype=float32)
# tf.Tensor(0.1982063, shape=(), dtype=float32)
# tf.Tensor(0.198157, shape=(), dtype=float32)
# tf.Tensor(0.19813101, shape=(), dtype=float32)
# tf.Tensor(0.1981171, shape=(), dtype=float32)
# tf.Tensor(0.19810952, shape=(), dtype=float32)
# tf.Tensor(0.19810526, shape=(), dtype=float32)
# tf.Tensor(0.19810265, shape=(), dtype=float32)
# tf.Tensor(0.19810095, shape=(), dtype=float32)
# tf.Tensor(0.19809975, shape=(), dtype=float32)
# tf.Tensor(0.19809878, shape=(), dtype=float32)
# tf.Tensor(0.19809794, shape=(), dtype=float32)
# tf.Tensor(0.19809718, shape=(), dtype=float32)
# tf.Tensor(0.19809642, shape=(), dtype=float32)
# tf.Tensor(0.19809574, shape=(), dtype=float32)
# tf.Tensor(0.19809502, shape=(), dtype=float32)
# tf.Tensor(0.19809437, shape=(), dtype=float32)
# tf.Tensor(0.19809371, shape=(), dtype=float32)
# tf.Tensor(0.19809303, shape=(), dtype=float32)
# tf.Tensor(0.19809237, shape=(), dtype=float32)
# tf.Tensor(0.19809175, shape=(), dtype=float32)
# tf.Tensor(0.19809109, shape=(), dtype=float32)
# tf.Tensor(0.19809045, shape=(), dtype=float32)
# tf.Tensor(0.19808981, shape=(), dtype=float32)
# tf.Tensor(0.1980892, shape=(), dtype=float32)
# tf.Tensor(0.19808859, shape=(), dtype=float32)
