# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import seaborn as sns

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

import tensorflow_model_optimization as tfmot

# %%
import tempfile
import pathlib

tmpdir = tempfile.mkdtemp()

# %%
x=np.linspace(0,2*np.pi,360)

# %%
y=np.sin(x)

# %%
plt.plot(x,y)

# %%
## Model 1
model = keras.Sequential([layers.Dense(units=10, input_shape=[1])])
model.add(layers.Dense(units=10,activation='tanh')) #hidden layer
model.add(layers.Dense(units=10,activation='tanh')) #hidden layer
model.add(layers.Dense(units=10,activation='tanh')) #hidden layer
model.add(layers.Dense(units=10,activation='tanh')) #hidden layer

model.add(layers.Dense(units=1))
# Out:
# 2023-03-21 18:12:16.109856: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
# Model 2

#model = Sequential([Dense(10, input_shape=(1,)), Activation('tanh'), Dense(3),Activation('tanh'),Dense(1)])
#model = keras.Sequential([layers.Dense(units=10, input_shape=[1])])
#model.add(layers.Dense(units=10,activation='tanh')) #hidden layer


#model.add(layers.Dense(units=1))

# %%
#model = keras.Sequential([layers.Dense(units=4, input_shape=[1])])
#model.add(layers.Dense(units=3)) #hidden layer



#model.add(layers.Dense(units=1))

# %%
opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mean_squared_error', optimizer='SGD', metrics=['mean_squared_error'])

# %%
history = model.fit(x,y,batch_size=len(x),  epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 1s 557ms/step - loss: 0.5214 - mean_squared_error: 0.5214
# Epoch 2/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4892 - mean_squared_error: 0.4892
# Epoch 3/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4675 - mean_squared_error: 0.4675
# Epoch 4/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4522 - mean_squared_error: 0.4522
# Epoch 5/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4406 - mean_squared_error: 0.4406
# Epoch 6/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4313 - mean_squared_error: 0.4313
# Epoch 7/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4233 - mean_squared_error: 0.4233
# Epoch 8/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4160 - mean_squared_error: 0.4160
# Epoch 9/5000
# ...

# %%
model.evaluate(x, y)
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# [0.004650521092116833, 0.004650521092116833]

# %%
plt.plot(history.history['mean_squared_error'], label='mean_squared_error')
plt.figure()
plt.plot(history.history['loss'], label='loss')
#plt.plot(history.history['val_loss'], label='val_loss')
#plt.ylim([0, 10])
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
predictions = model.predict(x)

plt.plot(x, y, 'b', x, predictions, 'r--')
plt.plot(x, predictions, 'r--')

#plt.ylabel('Y / Predicted Value')
#plt.xlabel('X Value')
# Out:
# 12/12 [==============================] - 0s 1ms/step

# %%
# Add a small random number to each y value
#y_values += 0.1 * np.random.randn(*y_values.shape)

# Plot our data
#plt.plot(x_values, y_values, 'b.')
#plt.show()

# %%
# Convert to a model
MODELS_DIR = 'models/'
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)
MODEL_TF = MODELS_DIR + 'sinemodel'
MODEL_NO_QUANT_TFLITE = MODELS_DIR + 'model_no_quant.tflite'
MODEL_TFLITE = MODELS_DIR + 'sinemodel.tflite'
MODEL_TFLITE_MICRO = MODELS_DIR + 'sinemodel.cc'

# %%
net_save_path = os.path.join(tmpdir, "net/1/")
savedir="/home/fred/"
net_save_path = os.path.join(tmpdir, "net/1/")
tf.saved_model.save(model, net_save_path)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpcoekyvg6/net/1/assets
# INFO:tensorflow:Assets written to: /tmp/tmpcoekyvg6/net/1/assets

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(net_save_path) # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open('models/sinemodel.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
model_size = os.stat('models/sinemodel.tflite').st_size

# %%
print(model_size)
# Out:
# 5248

# %%
# Install xxd if it is not available

# Convert to a C source file, i.e, a TensorFlow Lite for Microcontrollers model
# !xxd -i {MODEL_TFLITE} > {MODEL_TFLITE_MICRO}
# Update variable names
REPLACE_TEXT = MODEL_TFLITE.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'g_sine_model_data[] DATA_ALIGN_ATTRIBUTE' {MODEL_TFLITE_MICRO}
# Out:
# sed: -e expression #1, char 65: unterminated `s' command

# %%
#for layer in model.layers: print( layer.get_weights())

# %%
# Define model for pruning.
batch_size=len(x)
epochs=2
num_features = x.shape[0] * 1
end_step = np.ceil(num_features / batch_size).astype(np.int32) * epochs

#end_step = np.ceil(num_features / batch_size).astype(np.int32) * epochs

# Define model for pruning.
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.0,final_sparsity=0.9,begin_step=0,end_step=end_step)
}
pruning_schedule = tfmot.sparsity.keras.ConstantSparsity(
    target_sparsity=0.3, begin_step=0, end_step=100, frequency=100
)

#model_for_pruning = tfmot.sparsity.keras.prune_low_magnitude(model, **pruning_params)
model_for_pruning = tfmot.sparsity.keras.prune_low_magnitude(model,pruning_schedule=pruning_schedule)
# `prune_low_magnitude` requires a recompile.
#model_for_pruning.compile(loss='mean_squared_error', optimizer='SGD', metrics=['mean_squared_error'])
model_for_pruning.compile(
    loss="mean_squared_error",
    optimizer='SGD', metrics=['mean_squared_error']
)
#model_for_pruning.summary()
# Out:
# WARNING:tensorflow:From /home/fred/.local/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/fred/.local/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
#model.summary()

# %%
from keras_visualizer import visualizer 
visualizer(model,  filename='graph',format='png', view=True)

# %%
#visualizer(model_for_pruning,  filename='graph2',format='png', view=True)

# %%
batch_size=len(x)
print(batch_size)
batch_size=batch_size/2
print(batch_size)
log_dir = tempfile.mkdtemp()

callbacks = [
    tfmot.sparsity.keras.UpdatePruningStep(),
    # Log sparsity and other metrics in Tensorboard.
    #tfmot.sparsity.keras.PruningSummaries(log_dir=log_dir)
]


history2=model_for_pruning.fit(x,y,batch_size=len(x), callbacks=[tfmot.sparsity.keras.UpdatePruningStep()], epochs=5000)
# Out:
# 360
# 180.0
# Epoch 1/5000
# 1/1 [==============================] - 3s 3s/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 2/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 3/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 4/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 5/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 6/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 7/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 8/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 9/5000
# ...

# %%
#model_for_pruning.summary()

# %%
plt.plot(history2.history['mean_squared_error'], label='mean_squared_error')
plt.figure()
plt.plot(history2.history['loss'], label='loss')
#plt.plot(history.history['val_loss'], label='val_loss')
#plt.ylim([0, 10])
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
model.evaluate(x, y)
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 8.6452e-04 - mean_squared_error: 8.6452e-04
# [0.0008645234047435224, 0.0008645234047435224]

# %%
model_for_pruning.evaluate(x, y)
# Out:
# 12/12 [==============================] - 0s 2ms/step - loss: 8.6452e-04 - mean_squared_error: 8.6452e-04
# [0.0008645234047435224, 0.0008645234047435224]

# %%
# Convert to a model
MODELS_DIR = 'models/'
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)
MODEL2_TF = MODELS_DIR + 'sinemodel2'
MODEL2_NO_QUANT_TFLITE = MODELS_DIR + 'model_no_quant2.tflite'
MODEL2_TFLITE = MODELS_DIR + 'sinemodel2.tflite'
MODEL2_TFLITE_MICRO = MODELS_DIR + 'sinemodel2.cc'

# %%
net_save_path2 = os.path.join(tmpdir, "net/1/")
savedir2="/home/fred/"
net_save_path2 = os.path.join(tmpdir, "net/1/")
tf.saved_model.save(model_for_pruning, net_save_path2)
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla, dense_layer_call_fn, dense_layer_call_and_return_conditional_losses, dense_1_layer_call_fn, dense_1_layer_call_and_return_conditional_losses while saving (showing 5 of 13). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpcoekyvg6/net/1/assets
# INFO:tensorflow:Assets written to: /tmp/tmpcoekyvg6/net/1/assets

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(net_save_path2) # path to the SavedModel directory
tflite_model2 = converter.convert()

# Save the model.
with open('models/sinemodel2.tflite', 'wb') as f:
  f.write(tflite_model2)

# %%
model2_size = os.stat('models/sinemodel2.tflite').st_size
print(model2_size)
# Out:
# 14840

# %%
print(model_size)
# Out:
# 5248

# %%
predictions2 = model_for_pruning.predict(x)

plt.plot(x, y, 'b', x, predictions, 'r--')
plt.plot(x, predictions, 'r--')

#plt.ylabel('Y / Predicted Value')
#plt.xlabel('X Value')
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
#for layer in model_for_pruning.layers: print( layer.get_weights())

# %%
# Install xxd if it is not available

# Convert to a C source file, i.e, a TensorFlow Lite for Microcontrollers model
# !xxd -i {MODEL2_TFLITE} > {MODEL2_TFLITE_MICRO}
# Update variable names
REPLACE_TEXT = MODEL2_TFLITE.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'g_sine_model_data[] DATA_ALIGN_ATTRIBUTE' {MODEL2_TFLITE_MICRO}
# Out:
# sed: -e expression #1, char 66: unterminated `s' command
